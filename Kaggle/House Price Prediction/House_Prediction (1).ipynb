# %%
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv('/content/train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
test=pd.read_csv('/content/test.csv')

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
test.shape
# Out:
# (1459, 80)

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
def missing (df):
    missing_number = df.isnull().sum().sort_values(ascending=False)
    missing_percent = ((df.isnull().sum()/df1.isnull().count())*100).sort_values(ascending=False)
    missing_values = pd.concat([missing_number, missing_percent], axis=1, keys=['Missing_Number', 'Missing_Percent'])
    return missing_values

# %%
for col in df.columns:
    if df[col].isnull().mean()*100>40:
        df.drop(col,axis=1,inplace=True)
df.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 76, dtype: int64

# %%
df.duplicated().any()
# Out:
# False

# %%
df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
count=1
plt.subplots(figsize=(30,25))
for i in df.columns:
    if df[i].dtypes!='object':
        plt.subplot(6,7,count)
        sns.distplot(df[i],bins='auto')
        count+=1

plt.show()

# %%
count=1
plt.subplots(figsize=(30,25))
for i in df.columns:
    if df[i].dtypes!='object':
        plt.subplot(6,7,count)
        sns.boxplot(df[i])
        count+=1

plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.histplot(df['SalePrice'],bins='auto',kde=True)
plt.subplot(1,2,2)
sns.boxplot(df['SalePrice'],orient='vertical',color='green');

# %%
corr=df.corr()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(corr,annot=True,vmax=0.9)

# %%
df1=df

# %%
from sklearn.preprocessing import LabelEncoder
from scipy.stats import zscore


col=df1.columns
le=LabelEncoder()
for i in col:
    df1[i]=le.fit_transform(df1[i])

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.ensemble import AdaBoostClassifier


X=df1.drop('SalePrice',axis=1)
y=df1['SalePrice']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
print(" X_train dataset: ", X_train.shape)
print(" y_train dataset: ", y_train.shape)
print(" X_test dataset: ", X_test.shape)
print(" y_test dataset: ", y_test.shape)
# Out:
#  X_train dataset:  (1022, 75)
#  y_train dataset:  (1022,)
#  X_test dataset:  (438, 75)
#  y_test dataset:  (438,)

# %%
from scipy.stats import zscore
XScaled=X.apply(zscore)

# %%
tree = DecisionTreeRegressor()
tree.fit(X_train, y_train)
y_pred_tree = tree.predict(X_test)

print('Accuracy on Training data:',tree.score(X_train, y_train) )  
print('Accuracy on Test data:',tree.score(X_test, y_test) )
# Out:
# Accuracy on Training data: 1.0
# Accuracy on Test data: 0.8027275049366802

# %%
  rf = RandomForestRegressor()
  rf.fit(X_train, y_train)
  y_pred_tree = rf.predict(X_test)

  print('Accuracy on Training data:',rf.score(X_train, y_train) )  
  print('Accuracy on Test data:',rf.score(X_test, y_test) )
# Out:
# Accuracy on Training data: 0.982701832068058
# Accuracy on Test data: 0.9117731022916186

# %%
from sklearn.decomposition import PCA

# %%
covmatrix=np.cov(df, rowvar=False)
print(covmatrix)
# Out:
# [[ 1.77755000e+05  3.28920493e+01 -1.62440027e+00 ...  1.29393420e+01
#   -2.69465387e+00 -1.61523509e+03]
#  [ 3.28920493e+01  1.73218338e+01  9.93897115e-02 ...  1.30457623e-01
#   -1.51640268e-01 -2.86445445e+01]
#  [-1.62440027e+00  9.93897115e-02  3.99446046e-01 ...  9.55815111e-02
#    6.60519966e-03 -2.48367431e+01]
#  ...
#  [ 1.29393420e+01  1.30457623e-01  9.55815111e-02 ...  2.40901490e+00
#    3.14502803e-01 -9.18625536e+00]
#  [-2.69465387e+00 -1.51640268e-01  6.60519966e-03 ...  3.14502803e-01
#    1.21188044e+00  4.41532810e+01]
#  [-1.61523509e+03 -2.86445445e+01 -2.48367431e+01 ... -9.18625536e+00
#    4.41532810e+01  2.88046465e+04]]

# %%
pca=PCA(n_components=75)
pca.fit(XScaled)
# Out:
# PCA(n_components=75)

# %%
#eigen_vectors
print(pca.components_)
# Out:
# [[-0.00276432 -0.00110282 -0.08229001 ... -0.00677871 -0.01899591
#    0.07470612]
#  [ 0.00967049  0.11378468  0.01169683 ... -0.03502477  0.0013934
#   -0.00357619]
#  [-0.00528907 -0.20058379  0.07376108 ... -0.00792122 -0.00076724
#   -0.05977937]
#  ...
#  [-0.01223621 -0.34804288 -0.02981605 ... -0.01021431 -0.01361417
#    0.01263373]
#  [-0.006017   -0.17540246  0.00741603 ... -0.00848494 -0.00062097
#    0.00208284]
#  [-0.00669785  0.04324439  0.0084095  ...  0.00090825 -0.00325325
#    0.00749675]]

# %%
#eigen_values
print(pca.explained_variance_)
# Out:
# [10.42440246  4.07297619  3.67294703  2.9300903   2.31203171  2.06772305
#   1.98433757  1.75999901  1.65655201  1.56039251  1.53468659  1.44511617
#   1.33507595  1.31113837  1.26255262  1.20528781  1.18843538  1.15826664
#   1.12332609  1.11768713  1.10152454  1.05929743  1.04697433  0.99188936
#   0.97714534  0.96367997  0.95138212  0.92268202  0.8954085   0.87679853
#   0.85185075  0.83249185  0.82409342  0.80901379  0.78363427  0.77840443
#   0.76266321  0.74994315  0.70618707  0.7034263   0.67106117  0.63832589
#   0.61524723  0.61039129  0.59285247  0.58200944  0.55968064  0.55216403
#   0.50084691  0.49044931  0.4841129   0.46796646  0.44391141  0.41862469
#   0.40011279  0.39694396  0.38029212  0.35648939  0.33942491  0.30435688
#   0.29913277  0.28909856  0.25722752  0.24637424  0.22423804  0.21641402
#   0.21039099  0.16651416  0.13607743  0.1304622   0.10830374  0.09619517
#   0.08411653  0.04488487  0.02519599]

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.13889683 0.05426915 0.04893908 0.03904111 0.03080597 0.02755076
#  0.02643971 0.02345058 0.02207223 0.02079098 0.02044847 0.01925502
#  0.01778882 0.01746987 0.0168225  0.0160595  0.01583495 0.01543298
#  0.01496742 0.01489229 0.01467693 0.01411429 0.0139501  0.01321613
#  0.01301968 0.01284027 0.01267641 0.012294   0.0119306  0.01168264
#  0.01135023 0.01109229 0.01098039 0.01077946 0.0104413  0.01037162
#  0.01016188 0.00999239 0.00940938 0.00937259 0.00894135 0.00850518
#  0.00819768 0.00813298 0.00789929 0.00775481 0.0074573  0.00735714
#  0.00667338 0.00653485 0.00645042 0.00623528 0.00591476 0.00557784
#  0.00533118 0.00528896 0.00506709 0.00474994 0.00452257 0.00405531
#  0.00398571 0.00385201 0.00342735 0.00328274 0.00298779 0.00288354
#  0.00280329 0.00221867 0.00181312 0.0017383  0.00144306 0.00128172
#  0.00112079 0.00059805 0.00033572]

# %%
plt.figure(figsize=(10,7))
plt.step(list(range(75)), np.cumsum(pca.explained_variance_ratio_)*100 ,where='mid')
plt.ylabel('Cum of variation explained')
plt.xlabel('Components')
plt.show()

# %%
pca1=PCA(n_components=60)
pca1.fit(XScaled)
# Out:
# PCA(n_components=60)

# %%
Xpca=pca1.transform(XScaled)

# %%
x=Xpca
y=df['SalePrice']


X_train_pca, X_test_pca, y_train_pca, y_test_pca = train_test_split(x,y, test_size = 0.3, random_state=10)

print(" X_train-pca dataset: ", X_train_pca.shape)
print(" y_train_pca dataset: ", y_train_pca.shape)
print(" X_test_pca dataset: ", X_test_pca.shape)
print(" y_test_pca dataset: ", y_test_pca.shape)
# Out:
#  X_train-pca dataset:  (1022, 60)
#  y_train_pca dataset:  (1022,)
#  X_test_pca dataset:  (438, 60)
#  y_test_pca dataset:  (438,)

# %%
tree_pca = DecisionTreeRegressor()
tree_pca.fit(X_train_pca, y_train_pca)
y_pred_tree_pca = tree_pca.predict(X_test_pca)

print('Accuracy on Training data:',tree_pca.score(X_train_pca, y_train_pca) )  
print('Accuracy on Test data:',tree_pca.score(X_test_pca, y_test_pca) )
# Out:
# Accuracy on Training data: 1.0
# Accuracy on Test data: 0.7499522747040632

# %%
model_pca = RandomForestRegressor()
model_pca.fit(X_train_pca, y_train_pca)
y_pred_model_pca = model_pca.predict(X_test_pca)

print('Accuracy on Training data:',model_pca.score(X_train_pca, y_train_pca) )  
print('Accuracy on Test data:',model_pca.score(X_test_pca, y_test_pca) )
# Out:
# Accuracy on Training data: 0.9831402638464476
# Accuracy on Test data: 0.8771415269050242

# %%
from sklearn.model_selection import GridSearchCV

model=DecisionTreeRegressor()
parameters=[{'criterion' : ["squared_error", "friedman_mse", "absolute_error","poisson"],
              "min_samples_split": [10, 20, 40],
              "max_depth": [2, 6, 8],
              "min_samples_leaf": [20, 40, 100],
              "max_leaf_nodes": [5, 20, 100]}]

# %%
grid_search = GridSearchCV(estimator = model,
                           param_grid = parameters,
                           cv = 3,)

# %%
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeRegressor(),
#              param_grid=[{'criterion': ['squared_error', 'friedman_mse',
#                                         'absolute_error', 'poisson'],
#                           'max_depth': [2, 6, 8],
#                           'max_leaf_nodes': [5, 20, 100],
#                           'min_samples_leaf': [20, 40, 100],
#                           'min_samples_split': [10, 20, 40]}])

# %%
print(grid_search.best_params_)
# Out:
# {'criterion': 'absolute_error', 'max_depth': 8, 'max_leaf_nodes': 100, 'min_samples_leaf': 20, 'min_samples_split': 20}

# %%
tree_grid = DecisionTreeRegressor(criterion='absolute_error', max_depth= 8, max_leaf_nodes= 100, min_samples_leaf= 20, min_samples_split= 10)
tree_grid.fit(X_train_pca, y_train_pca)
y_pred_tree_grid = tree_grid.predict(X_test_pca)

print('Accuracy on Training data:',tree_grid.score(X_train_pca, y_train_pca) )  
print('Accuracy on Test data:',tree_grid.score(X_test_pca, y_test_pca) )
# Out:
# Accuracy on Training data: 0.8828887304960795
# Accuracy on Test data: 0.8368596774409167

# %%
model2=RandomForestRegressor()
parameters=[{'criterion' : ["squared_error", "absolute_error","poisson"],
              "min_samples_split": [10, 20, 40],
              "max_depth": [2, 6, 8],
              "min_samples_leaf": [20, 40, 100],
              "max_leaf_nodes": [5, 20, 100]}]

# %%
grid_search = GridSearchCV(estimator = model2,
                           param_grid = parameters,
                           cv = 3,)

# %%
rf_grid = RandomForestRegressor(criterion='squared_error', max_depth= 10, max_leaf_nodes= 100, min_samples_leaf= 1, min_samples_split= 8)
rf_grid.fit(X_train_pca, y_train_pca)
y_pred_rf_grid = rf_grid.predict(X_test_pca)

print('Accuracy on Training data:',rf_grid.score(X_train_pca, y_train_pca) )  
print('Accuracy on Test data:',rf_grid.score(X_test_pca, y_test_pca) )
# Out:
# Accuracy on Training data: 0.9715087440748467
# Accuracy on Test data: 0.8779473675973561

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
test.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 80, dtype: int64

# %%
for col in test.columns:
    if test[col].isnull().mean()*100>40:
        test.drop(col,axis=1,inplace=True)

# %%
f = lambda x: x.median() if np.issubdtype(x.dtype, np.number) else x.mode().iloc[0]
test = test.fillna(test.groupby('YrSold').transform(f))
test.isna().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 75, dtype: int64

# %%
le=LabelEncoder()
for col in test.columns:
    if test[col].dtypes == 'object':
        test[col]= le.fit_transform(test[col])

# %%
test.head()
# Out:
#      Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0  1461          20         2           80    11622       1         3
# 1  1462          20         3           81    14267       1         0
# 2  1463          60         3           74    13830       1         0
# 3  1464          60         3           78     9978       1         0
# 4  1465         120         3           43     5005       1         0
#
#    LandContour  Utilities  LotConfig  ...  OpenPorchSF  EnclosedPorch  \
# 0            3          0          4  ...            0              0
# 1            3          0          0  ...           36              0
# 2            3          0          4  ...           34              0
# 3            3          0          4  ...           36              0
# 4            1          0          4  ...           82              0
#
#    3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  \
# ...

# %%
rf.fit(X,y)
y_pred=rf.predict(test)

# %%
submission=pd.DataFrame({'Id':test['Id'],
                         'Survived':y_pred })

# %%
submission.to_csv("House_submission.csv", index=False)
submission.head()
# Out:
#      Id  Survived
# 0  1461    328.02
# 1  1462    512.63
# 2  1463    435.24
# 3  1464    522.47
# 4  1465    465.36
